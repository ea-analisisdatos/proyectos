# %%
import seaborn as sns
# %matplotlib inline
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
sns.set()

# %%
# Definir la ruta donde se encuentra la carpeta y los CSVs que iremos trabajar
#ruta_datos_preprocesados = '../data/ficheros_procesados/datos_preprocesados_limpios.csv'
ruta_datos_preprocesados = '../data/ficheros_procesados/datos_preprocesados.csv'

# Creación del DataFrame
df = pd.read_csv(ruta_datos_preprocesados, delimiter=",", engine="python")
df.head()
# Out:
#     ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 0  2015   Islandia  Europa Occidental            7.561
# 1  2015  Dinamarca  Europa Occidental            7.527
# 2  2015    Noruega  Europa Occidental            7.522
# 3  2015  Finlandia  Europa Occidental            7.406
# 4  2015     Suecia  Europa Occidental            7.364
#
#    ECONOMIA_PIB_PER_CAPITA  APOYO_SOCIAL  SALUD_ESPERANZA_DE_VIDA  LIBERTAD  \
# 0                  1.30232       1.40223                  0.94784   0.62877
# 1                  1.32548       1.36058                  0.87464   0.64938
# 2                  1.45900       1.33095                  0.88521   0.66973
# 3                  1.29025       1.31826                  0.88911   0.64169
# 4                  1.33171       1.28907                  0.91087   0.65980
#
#    PERCEPCION_CORRUPCION  GENEROSIDAD
# 0                0.14145      0.43630
# 1                0.48357      0.34139
# 2                0.36503      0.34699
# ...

# %%
# Algoritmo ranking - Crea top 10 and bottom 10 identificación columna

def top_bottom_identifier(value):
    if value < 11:
        return "top 10 happiest"
    if value > 127:
        return "bottom 10 happiest"
    elif 11 <= value < 128:
        return "not top/bottom 10"
    
df['top_bottom_identifier'] = df['FELICIDAD_SCORE'].map(top_bottom_identifier)
df.head()
# Out:
#     ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 0  2015   Islandia  Europa Occidental            7.561
# 1  2015  Dinamarca  Europa Occidental            7.527
# 2  2015    Noruega  Europa Occidental            7.522
# 3  2015  Finlandia  Europa Occidental            7.406
# 4  2015     Suecia  Europa Occidental            7.364
#
#    ECONOMIA_PIB_PER_CAPITA  APOYO_SOCIAL  SALUD_ESPERANZA_DE_VIDA  LIBERTAD  \
# 0                  1.30232       1.40223                  0.94784   0.62877
# 1                  1.32548       1.36058                  0.87464   0.64938
# 2                  1.45900       1.33095                  0.88521   0.66973
# 3                  1.29025       1.31826                  0.88911   0.64169
# 4                  1.33171       1.28907                  0.91087   0.65980
#
#    PERCEPCION_CORRUPCION  GENEROSIDAD top_bottom_identifier
# 0                0.14145      0.43630       top 10 happiest
# ...

# %%
df.iloc[df['ECONOMIA_PIB_PER_CAPITA'].argmax()]
# Out:
# ANO                                     2022
# PAIS                                 Noruega
# REGION                     Europa Occidental
# FELICIDAD_SCORE                        7.365
# ECONOMIA_PIB_PER_CAPITA                1.997
# APOYO_SOCIAL                           1.239
# SALUD_ESPERANZA_DE_VIDA                0.786
# LIBERTAD                               0.728
# PERCEPCION_CORRUPCION                  0.474
# GENEROSIDAD                            0.217
# top_bottom_identifier        top 10 happiest
# Name: 46, dtype: object

# %%
# Se usa para encontrar la correlación por pares de todas las columnas en el marco de datos (dataframe). 
# Cualquer valor NA se excluye automáticamente. Para cualquer columna de tipo de datos no numérico en 
# el dataframe, se ignora
df.corr(method='pearson')
# Out:
# C:\Users\Erika\AppData\Local\Temp\ipykernel_32364\1732860982.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                               ANO  FELICIDAD_SCORE  ECONOMIA_PIB_PER_CAPITA  \
# ANO                      1.000000         0.078003                 0.691464
# FELICIDAD_SCORE          0.078003         1.000000                 0.198114
# ECONOMIA_PIB_PER_CAPITA  0.691464         0.198114                 1.000000
# APOYO_SOCIAL             0.045982         0.118682                -0.070473
# SALUD_ESPERANZA_DE_VIDA -0.498571        -0.164343                -0.772800
# LIBERTAD                 0.406777         0.828379                 0.533296
# PERCEPCION_CORRUPCION    0.223672         0.670458                 0.337951
# ...

# %%
df[df.ECONOMIA_PIB_PER_CAPITA == 1.30232]
df[df.ECONOMIA_PIB_PER_CAPITA > 1.49438726902008]
# Out:
#      ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 8   2016    Noruega  Europa Occidental            7.498
# 12  2017    Noruega  Europa Occidental            7.537
# 37  2021  Dinamarca  Europa Occidental            7.620
# 39  2021    Noruega  Europa Occidental            7.392
# 42  2022  Finlandia  Europa Occidental            7.821
# 43  2022  Dinamarca  Europa Occidental            7.636
# 44  2022   Islandia  Europa Occidental            7.557
# 45  2022     Suecia  Europa Occidental            7.384
# 46  2022    Noruega  Europa Occidental            7.365
# 47  2022     España  Europa Occidental            6.476
# 48  2023  Dinamarca  Europa Occidental            7.586
# 49  2023  Finlandia  Europa Occidental            7.804
# 50  2023   Islandia  Europa Occidental            7.530
# 51  2023    Noruega  Europa Occidental            7.315
# 52  2023     España  Europa Occidental            6.436
# 53  2023     Suecia  Europa Occidental            7.395
#
# ...

# %%
df_per_capita = df["PAIS"]
df_per_capita.head()
# Out:
# 0     Islandia
# 1    Dinamarca
# 2      Noruega
# 3    Finlandia
# 4       Suecia
# Name: PAIS, dtype: object

# %%
# df_seleccionado = df.groupby('PAIS')['ECONOMIA_PIB_PER_CAPITA'].transform('mean')
# df_seleccionado

# %%
df.loc[df.ECONOMIA_PIB_PER_CAPITA > 1]
df.head()
# Out:
#     ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 0  2015   Islandia  Europa Occidental            7.561
# 1  2015  Dinamarca  Europa Occidental            7.527
# 2  2015    Noruega  Europa Occidental            7.522
# 3  2015  Finlandia  Europa Occidental            7.406
# 4  2015     Suecia  Europa Occidental            7.364
#
#    ECONOMIA_PIB_PER_CAPITA  APOYO_SOCIAL  SALUD_ESPERANZA_DE_VIDA  LIBERTAD  \
# 0                  1.30232       1.40223                  0.94784   0.62877
# 1                  1.32548       1.36058                  0.87464   0.64938
# 2                  1.45900       1.33095                  0.88521   0.66973
# 3                  1.29025       1.31826                  0.88911   0.64169
# 4                  1.33171       1.28907                  0.91087   0.65980
#
#    PERCEPCION_CORRUPCION  GENEROSIDAD top_bottom_identifier
# 0                0.14145      0.43630       top 10 happiest
# ...

# %%
df_filtered = df[(df['ANO'] == 2017) | (df['ANO'] == 2020)]

df_filtered.head(100)
# Out:
#      ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 12  2017    Noruega  Europa Occidental           7.5370
# 13  2017  Dinamarca  Europa Occidental           7.5220
# 14  2017   Islandia  Europa Occidental           7.5040
# 15  2017  Finlandia  Europa Occidental           7.4690
# 16  2017     Suecia  Europa Occidental           7.2840
# 17  2017     España  Europa Occidental           6.4030
# 30  2020  Finlandia  Europa Occidental           7.8087
# 31  2020  Dinamarca  Europa Occidental           7.6456
# 32  2020   Islandia  Europa Occidental           7.5045
# 33  2020    Noruega  Europa Occidental           7.4880
# 34  2020     Suecia  Europa Occidental           7.3535
# 35  2020     España  Europa Occidental           6.4009
#
#     ECONOMIA_PIB_PER_CAPITA  APOYO_SOCIAL  SALUD_ESPERANZA_DE_VIDA  LIBERTAD  \
# 12                 1.616463      1.533524                 0.796667  0.635423
# 13                 1.482383      1.551122                 0.792566  0.626007
# ...

# %%
df_filtered = df[(df['ECONOMIA_PIB_PER_CAPITA'] == 1.997 ) & (df['ANO'] != 2017) | (df['ANO'] != 2020)] 
df_filtered.head(100)
# Out:
#      ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 0   2015   Islandia  Europa Occidental            7.561
# 1   2015  Dinamarca  Europa Occidental            7.527
# 2   2015    Noruega  Europa Occidental            7.522
# 3   2015  Finlandia  Europa Occidental            7.406
# 4   2015     Suecia  Europa Occidental            7.364
# 5   2015     España  Europa Occidental            6.329
# 6   2016  Dinamarca  Europa Occidental            7.526
# 7   2016   Islandia  Europa Occidental            7.501
# 8   2016    Noruega  Europa Occidental            7.498
# 9   2016  Finlandia  Europa Occidental            7.413
# 10  2016     Suecia  Europa Occidental            7.291
# 11  2016     España  Europa Occidental            6.361
# 12  2017    Noruega  Europa Occidental            7.537
# 13  2017  Dinamarca  Europa Occidental            7.522
# 14  2017   Islandia  Europa Occidental            7.504
# 15  2017  Finlandia  Europa Occidental            7.469
# ...

# %%
df_filtered = df[(df['ECONOMIA_PIB_PER_CAPITA'] == 1.997000 ) & (df['ANO'] != 2017) & (df['ANO'] != 2020)] 
df_filtered.head(100)
# Out:
#      ANO     PAIS             REGION  FELICIDAD_SCORE  \
# 46  2022  Noruega  Europa Occidental            7.365
#
#     ECONOMIA_PIB_PER_CAPITA  APOYO_SOCIAL  SALUD_ESPERANZA_DE_VIDA  LIBERTAD  \
# 46                    1.997         1.239                    0.786     0.728
#
#     PERCEPCION_CORRUPCION  GENEROSIDAD top_bottom_identifier
# 46                  0.474        0.217       top 10 happiest

# %%
df_filtered = df[(df['ECONOMIA_PIB_PER_CAPITA'] >= 1.49438726902008)] 
df_filtered.head(100)
# Out:
#      ANO       PAIS             REGION  FELICIDAD_SCORE  \
# 8   2016    Noruega  Europa Occidental            7.498
# 12  2017    Noruega  Europa Occidental            7.537
# 16  2017     Suecia  Europa Occidental            7.284
# 37  2021  Dinamarca  Europa Occidental            7.620
# 39  2021    Noruega  Europa Occidental            7.392
# 42  2022  Finlandia  Europa Occidental            7.821
# 43  2022  Dinamarca  Europa Occidental            7.636
# 44  2022   Islandia  Europa Occidental            7.557
# 45  2022     Suecia  Europa Occidental            7.384
# 46  2022    Noruega  Europa Occidental            7.365
# 47  2022     España  Europa Occidental            6.476
# 48  2023  Dinamarca  Europa Occidental            7.586
# 49  2023  Finlandia  Europa Occidental            7.804
# 50  2023   Islandia  Europa Occidental            7.530
# 51  2023    Noruega  Europa Occidental            7.315
# 52  2023     España  Europa Occidental            6.436
# ...
